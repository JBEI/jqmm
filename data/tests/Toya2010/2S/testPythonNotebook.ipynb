# %% [markdown]
# # Two Scale 13C Metabolic Flux Analysis (2S-13CMFA) test notebook

# %% [markdown]
# This python notebook uses the QMM library to reproduce all figures from the Garcia Martin et al paper

# %% [markdown]
# # Setup

# %%
import unittest, os, sys
from IPython.display import SVG
import ToyaData as TD
import shelve

# %%
cd /scratch/hgmartin_scratch/tests/TStests/paper/repo
# Out:
# /scratch0/hgmartin_scratch/tests/TStests/paper/repo

# %% [markdown]
# **CHANGE THIS DIRECTORY TO YOUR OWN DIRECTORY!!!!**

# %% [markdown]
# # Tests

# %% [markdown]
# ## Testing SBML files

# %%
SBMLtest = unittest.TestSuite()
SBMLtest.addTest(TD.testFiles('testFull'))
#SBMLtest.addTest(TD.testFiles('refreshSavedFiles'))

# %%
# %%time
unittest.TextTestRunner(stream=sys.stdout,verbosity=2).run(SBMLtest)
# Out:
# testFull (ToyaData.testFiles)
# Tests all of the strains ...
# ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 25.953s
#
# OK
# CPU times: user 25.8 s, sys: 176 ms, total: 25.9 s
# Wall time: 26 s
# <unittest.runner.TextTestResult run=1 errors=0 failures=0>

# %% [markdown]
# ## Testing 2S flux profiles

# %% [markdown]
# ### Quick test

# %%
fluxTest = unittest.TestSuite()
fluxTest.addTest(TD.testTSFluxCalculation('testQuick'))
#fluxTest.addTest(TD.testTSFluxCalculation('refreshSavedFiles'))

# %%
# %%time
unittest.TextTestRunner(stream=sys.stdout,verbosity=2).run(fluxTest)
# Out:
# testQuick (ToyaData.testTSFluxCalculation)
# Only tests the first of the strains ...
# ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 507.424s
#
# OK
# CPU times: user 4min 19s, sys: 57.5 s, total: 5min 16s
# Wall time: 8min 27s
# <unittest.runner.TextTestResult run=1 errors=0 failures=0>

# %% [markdown]
# ### Full test

# %%
fluxTest = unittest.TestSuite()
fluxTest.addTest(TD.testTSFluxCalculation('testFull'))
#fluxTest.addTest(TD.testTSFluxCalculation('refreshSavedFiles'))

# %%
# %%time
unittest.TextTestRunner(stream=sys.stdout,verbosity=2).run(fluxTest)
# Out:
# testFull (ToyaData.testTSFluxCalculation)
# Test all strains ...
# FAIL
# ...
# FAIL: testFull (ToyaData.testTSFluxCalculation)
# Test all strains
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/users/hgmartin/libraries/quantmodel/code/core/python_emu_gams/ToyaData.py", line 227, in testFull
#     self.testStrain(strain)
#   File "/users/hgmartin/libraries/quantmodel/code/core/python_emu_gams/ToyaData.py", line 217, in testStrain
#     self.compareFluxDict(fluxDictRF,fluxDictN,delta,elements='lohi',errMsg=errMsgAdd) # Comparing only lowest and highest flux values
#   File "/users/hgmartin/libraries/quantmodel/code/core/python_emu_gams/ToyaData.py", line 120, in compareFluxDict
#     self.assertTrue(noChange,msg=errmsg)
# AssertionError: Flux EX_glyclt_e_ changed from:
# [3.10733 : 6.36419592461 : 8.17297] to:
# [3.76027 : 6.86367436156 : 8.28175]
#  in strain pyk5h
#
# ...

# %% [markdown]
# ## Test figure content

# %% [markdown]
# ### ELVA

# %%
fluxTest = unittest.TestSuite()
fluxTest.addTest(TD.testELVA('testQuick'))
#fluxTest.addTest(TD.testELVA('refreshSavedFiles'))

# %%
unittest.TextTestRunner(stream=sys.stdout,verbosity=2).run(fluxTest)
# Out:
# testQuick (ToyaData.testELVA)
# Quick test for wt5h only ...
# ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 1101.246s
#
# OK
# <unittest.runner.TextTestResult run=1 errors=0 failures=0>

# %% [markdown]
# ## Relative constraining power

# %%
fluxTest = unittest.TestSuite()
fluxTest.addTest(TD.testConstPower('testQuick'))
#fluxTest.addTest(TD.testConstPower('refreshSavedFiles'))

# %%
unittest.TextTestRunner(stream=sys.stdout,verbosity=2).run(fluxTest)
# Out:
# testQuick (ToyaData.testConstPower)
# Quick test for wt5h only ...
# ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 139.410s
#
# OK
# <unittest.runner.TextTestResult run=1 errors=0 failures=0>

# %% [markdown]
# ## Predictions

# %%
fluxTest = unittest.TestSuite()
fluxTest.addTest(TD.testPredictions('testQuick'))
#fluxTest.addTest(TD.testPredictions('refreshSavedFiles'))

# %%
unittest.TextTestRunner(stream=sys.stdout,verbosity=2).run(fluxTest)
# Out:
# testQuick (ToyaData.testPredictions)
# Quick test for pyk5h only ...
# ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 683.677s
#
# OK
# <unittest.runner.TextTestResult run=1 errors=0 failures=0>

# %% [markdown]
# # Draw figures

# %% [markdown]
# ## Figure 4 (ELVA)

# %%
# %%time
TD.getFigure(4)
# Out:
# CPU times: user 4min 30s, sys: 1min 38s, total: 6min 8s
# Wall time: 9min 9s

# %% [markdown]
# ## Figure 5 (Relative constraint effect)

# %%
# %%time
TD.getFigure(5)
# Out:
# TS is 0.0215274063285 % of FVA
# TS is 0.120539887554 % of FVA
# CPU times: user 12.9 s, sys: 53.3 s, total: 1min 6s
# Wall time: 2min 18s
# /usr/lib/pymodules/python2.7/matplotlib/axes.py:4747: UserWarning: No labeled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labeled objects found. "

# %% [markdown]
# ## Figure 6 (cofactors balance)

# %%
# %%time
TD.getFigure(6)
# Out:
# CPU times: user 10.7 s, sys: 52 ms, total: 10.8 s
# Wall time: 10.7 s

# %% [markdown]
# ## Figure 7 (Robustness to labeling errors)

# %%
# %%time
TD.getFigure(7)
# Out:
# CPU times: user 8min 19s, sys: 3min 3s, total: 11min 23s
# Wall time: 19min 13s

# %% [markdown]
# ## Figure 8 (Robustness to stoichiometric errors)

# %%
# %%time
TD.getFigure(8,saved=False)
# Out:
# CPU times: user 8min 40s, sys: 2min 22s, total: 11min 3s
# Wall time: 16min 22s

# %% [markdown]
# ## Figure 9 (Extracellular metabolite prediction)

# %%
# %%time
TD.getFigure(9)
# Out:
# CPU times: user 12.6 s, sys: 55.6 s, total: 1min 8s
# Wall time: 2min 16s

# %% [markdown]
# ## Figure 10 (Comparison with COBRA predictions)

# %%
# %%time
TD.getFigure(10)
# Out:
# CPU times: user 6min 19s, sys: 3min 58s, total: 10min 17s
# Wall time: 16min 54s

# %% [markdown]
# ## Figure 11 (Metabolite labeling prediction)

# %%
# %%time
TD.getFigure(11)
# Out:
# CPU times: user 6min 12s, sys: 2min 6s, total: 8min 18s
# Wall time: 12min 50s

# %% [markdown]
# # Supplementary figures

# %% [markdown]
# ## Supp. figure 1-3 (Fits)

# %%
# %%time
TD.getSuppFigure(1)
# Out:
# CPU times: user 56.5 s, sys: 296 ms, total: 56.8 s
# Wall time: 56.8 s

# %% [markdown]
# ## Supp. figure 4-12 (Flux maps)

# %%
# %%time
TD.getSuppFigure(4)
# Out:
# svgin:
# /users/hgmartin/libraries/quantmodel/code/visualization/fluxes/TOYAexp.svg
# svgin:
# /users/hgmartin/libraries/quantmodel/code/visualization/fluxes/TOYAexp.svg
# svgin:
# /users/hgmartin/libraries/quantmodel/code/visualization/fluxes/TOYAexp.svg
# svgin:
# /users/hgmartin/libraries/quantmodel/code/visualization/fluxes/TOYAexp.svg
# svgin:
# /users/hgmartin/libraries/quantmodel/code/visualization/fluxes/TOYAexp.svg
# svgin:
# /users/hgmartin/libraries/quantmodel/code/visualization/fluxes/TOYAexp.svg
# svgin:
# /users/hgmartin/libraries/quantmodel/code/visualization/fluxes/TOYAexp.svg
# svgin:
# /users/hgmartin/libraries/quantmodel/code/visualization/fluxes/TOYAexp.svg
# svgin:
# /users/hgmartin/libraries/quantmodel/code/visualization/fluxes/TOYAexp.svg
# CPU times: user 45.5 s, sys: 384 ms, total: 45.9 s
# Wall time: 46 s

# %% [markdown]
# ## Supp. figure 13-14 (Extracellular flux prediction for pyk and pgi KOs)

# %%
# %%time
TD.getSuppFigure(13)
# Out:
# CPU times: user 12.5 s, sys: 58.9 s, total: 1min 11s
# Wall time: 2min 23s

# %%
# %%time
TD.getSuppFigure(14)
# Out:
# CPU times: user 12.6 s, sys: 56 s, total: 1min 8s
# Wall time: 2min 16s

# %% [markdown]
# ## Supp. figure 15 (Robustness with respect to stoichiometric errors for GLUDy and ICDHyr)

# %%
# %%time
TD.getSuppFigure(15)
# Out:
# CPU times: user 12min 31s, sys: 3min 35s, total: 16min 6s
# Wall time: 22min 43s

# %% [markdown]
# ## Supp. figure 16 (13C MFA)

# %%
# %%time
TD.getSuppFigure(16)
# Out:
# svgin:
# /users/hgmartin/libraries/quantmodel/code/visualization/fluxes/TOYA13CMFA.svg
# CPU times: user 2.52 s, sys: 15.1 s, total: 17.6 s
# Wall time: 43 s

# %%
SVG(filename='ecoliwt5h13C.svg')

# %% [markdown]
# ## Supp. figure 17 (Full prediction comparison)

# %%
# %%time
TD.getSuppFigure(17)
# Out:
# CPU times: user 12min 34s, sys: 8min 8s, total: 20min 42s
# Wall time: 36min 48s

# %% [markdown]
# ## Supp. figure 18 (Partial prediction comparison)

# %%
# %%time
TD.getSuppFigure(18)
# Out:
# CPU times: user 57.9 s, sys: 5min 47s, total: 6min 45s
# Wall time: 13min 45s

# %% [markdown]
# ## Supp. figure 19 (OF vs N )

# %%
# %%time
TD.getSuppFigure(19)
# Out:
# [1, 2, 5, 10, 20, 30, 40, 50, 100]
# [2.677, 0.69325, 0.62501, 0.60903, 0.60903, 0.60903, 0.60903, 0.60903, 0.60903]
# CPU times: user 41min 28s, sys: 23min 34s, total: 1h 5min 3s
# Wall time: 1h 42min 3s
