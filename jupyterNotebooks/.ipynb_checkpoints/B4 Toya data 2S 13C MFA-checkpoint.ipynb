# %% [markdown]
# # B4: Toya data 2S 13C MFA

# %% [markdown]
# # Introduction

# %% [markdown]
# This notebook reproduces the figures in Garcia Martin et al 2015

# %% [markdown]
# # Setup

# %%
# %matplotlib inline

import sys, os
pythonPath = "/users/hgmartin/libraries/quantmodel/code/core"
if pythonPath not in sys.path:
    sys.path.append('/users/hgmartin/libraries/quantmodel/code/core')
os.environ["QUANTMODELPATH"] = '/users/hgmartin/libraries/quantmodel'

# %%
# %matplotlib inline
import unittest, os, sys
from IPython.display import SVG
import ToyaData as TD
import shelve

# %%
cd /scratch/hgmartin_scratch/tests
# Out:
# /scratch/hgmartin_scratch/tests

# %% [markdown]
# # Figures

# %% [markdown]
# ## Figure 4 (ELVA)

# %%
# %%time
TD.getFigure(4)
# Out:
# CPU times: user 9min 7s, sys: 52.6 s, total: 10min
# Wall time: 13min 18s

# %% [markdown]
# ## Figure 5 (Relative constraint effect)

# %%
# %%time
TD.getFigure(5)
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database',)).History will not be written to the database.
# TS is 0.0204094678396 % of FVA
# TS is 0.120233095891 % of FVA
# CPU times: user 8min 3s, sys: 2min 31s, total: 10min 35s
# Wall time: 18min 12s
# /usr/local/share/jupyteruser/.virtualenvs/jbeipython2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %% [markdown]
# ## Figure 6 (cofactors balance)

# %%
# %%time
TD.getFigure(6)
# Out:
# CPU times: user 34.3 s, sys: 148 ms, total: 34.4 s
# Wall time: 34.4 s

# %% [markdown]
# ## Figure 7 (Robustness to labeling errors)

# %%
# %%time
TD.getFigure(7)
# Out:
# CPU times: user 12min 30s, sys: 3min 10s, total: 15min 40s
# Wall time: 27min 23s

# %% [markdown]
# ## Figure 8 (Robustness to stoichiometric errors)

# %%
# %%time
TD.getFigure(8,saved=False)
# Out:
# CPU times: user 15min 29s, sys: 2min 30s, total: 18min
# Wall time: 24min 19s

# %% [markdown]
# ## Figure 9 (Extracellular metabolite prediction)

# %%
# %%time
TD.getFigure(9)
# Out:
# CPU times: user 25.7 s, sys: 1min 21s, total: 1min 47s
# Wall time: 4min 56s

# %% [markdown]
# ## Figure 10 (Comparison with COBRA predictions)

# %%
# %%time
TD.getFigure(10)
# Out:
# CPU times: user 12min 26s, sys: 4min 51s, total: 17min 17s
# Wall time: 26min 9s

# %% [markdown]
# ## Figure 11 (Metabolite labeling prediction)

# %%
# %%time
TD.getFigure(11)
# Out:
# CPU times: user 12min 2s, sys: 2min 34s, total: 14min 36s
# Wall time: 20min 53s

# %% [markdown]
# # Supplementary figures

# %% [markdown]
# ## Supp. figure 1-3 (Fits)

# %%
# %%time
TD.getSuppFigure(1)
# Out:
# CPU times: user 3min 6s, sys: 728 ms, total: 3min 6s
# Wall time: 3min 16s

# %% [markdown]
# ## Supp. figure 4-12 (Flux maps)

# %%
# %%time
TD.getSuppFigure(4)
# Out:
# svgin:
# /users/hgmartin/libraries/quantmodel/code/core/TOYAexpOLD2.svg
# svgin:
# /users/hgmartin/libraries/quantmodel/code/core/TOYAexpOLD2.svg
# svgin:
# /users/hgmartin/libraries/quantmodel/code/core/TOYAexpOLD2.svg
# svgin:
# /users/hgmartin/libraries/quantmodel/code/core/TOYAexpOLD2.svg
# svgin:
# /users/hgmartin/libraries/quantmodel/code/core/TOYAexpOLD2.svg
# svgin:
# /users/hgmartin/libraries/quantmodel/code/core/TOYAexpOLD2.svg
# svgin:
# /users/hgmartin/libraries/quantmodel/code/core/TOYAexpOLD2.svg
# svgin:
# /users/hgmartin/libraries/quantmodel/code/core/TOYAexpOLD2.svg
# svgin:
# /users/hgmartin/libraries/quantmodel/code/core/TOYAexpOLD2.svg
# CPU times: user 2min 37s, sys: 416 ms, total: 2min 37s
# Wall time: 2min 37s

# %% [markdown]
# ## Supp. figure 13-14 (Extracellular flux prediction for pyk and pgi KOs)

# %%
# %%time
TD.getSuppFigure(13)
# Out:
# CPU times: user 26.6 s, sys: 1min 5s, total: 1min 32s
# Wall time: 2min 50s

# %%
# %%time
TD.getSuppFigure(14)
# Out:
# CPU times: user 26.4 s, sys: 1min 5s, total: 1min 32s
# Wall time: 2min 50s

# %% [markdown]
# ## Supp. figure 15 (Robustness with respect to stoichiometric errors for GLUDy and ICDHyr)

# %%
# %%time
TD.getSuppFigure(15)
# Out:
# CPU times: user 24min 9s, sys: 4min 12s, total: 28min 21s
# Wall time: 39min 52s

# %% [markdown]
# ## Supp. figure 16 (13C MFA)

# %%
# %%time
TD.getSuppFigure(16)
# Out:
# svgin:
# /users/hgmartin/libraries/quantmodel/code/core/TOYA13CMFA.svg
# CPU times: user 6.99 s, sys: 15.6 s, total: 22.6 s
# Wall time: 44.9 s

# %% [markdown]
# ## Supp. figure 17 (Full prediction comparison)

# %%
# %%time
TD.getSuppFigure(17)
# Out:
# CPU times: user 26min 1s, sys: 9min 53s, total: 35min 55s
# Wall time: 59min 52s

# %% [markdown]
# ## Supp. figure 18 (Partial prediction comparison)

# %%
# %%time
TD.getSuppFigure(18)
# Out:
# CPU times: user 2min 57s, sys: 6min 39s, total: 9min 36s
# Wall time: 17min 27s

# %% [markdown]
# ## Supp. figure 19 (OF vs N )

# %% [markdown]
# WARNING: this figure takes **forever**!!!!!!

# %%
#%%time
#TD.getSuppFigure(19)
