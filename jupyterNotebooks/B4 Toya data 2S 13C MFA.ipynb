# %% [markdown]
# # B4: Toya data 2S 13C MFA

# %% [markdown]
# # Introduction

# %% [markdown]
# This notebook reproduces the figures in Garcia Martin et al 2015. This notebook takes a long time to run completely.

# %% [markdown]
# # Setup

# %% [markdown]
# First, we need to set the path and environment variable properly:

# %%
quantmodelDir = '/users/hgmartin/libraries/quantmodel'

# %% [markdown]
# This is the only place where the jQMM library path needs to be set.

# %%
# %matplotlib inline

import sys, os
pythonPath = quantmodelDir+"/code/core"
if pythonPath not in sys.path:
    sys.path.append(pythonPath)
os.environ["QUANTMODELPATH"] = quantmodelDir

# %%
# %matplotlib inline
import unittest, os, sys
from IPython.display import SVG
import ToyaData as TD
import shelve

# %% [markdown]
# And move to a scratch directory (to make things faster):

# %%
cd /scratch/hgmartin_scratch/tests
# Out:
# /scratch/hgmartin_scratch/tests

# %% [markdown]
# # Figures

# %% [markdown]
# ## Figure 4 (ELVA)

# %%
# %%time
TD.getFigure(4)
# Out:
# CPU times: user 9min 22s, sys: 55.2 s, total: 10min 17s
# Wall time: 13min 2s

# %% [markdown]
# ## Figure 5 (Relative constraint effect)

# %%
# %%time
TD.getFigure(5)
# Out:
# TS is 0.0204094678396 % of FVA
# TS is 0.120233095891 % of FVA
# CPU times: user 8min 35s, sys: 2min 27s, total: 11min 2s
# Wall time: 16min 15s
# /usr/local/share/jupyteruser/.virtualenvs/jbeipython2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %% [markdown]
# ## Figure 6 (cofactors balance)

# %%
# %%time
TD.getFigure(6)
# Out:
# CPU times: user 40.8 s, sys: 196 ms, total: 41 s
# Wall time: 40.9 s

# %% [markdown]
# ## Figure 7 (Robustness to labeling errors)

# %%
# %%time
TD.getFigure(7)
# Out:
# CPU times: user 12min 43s, sys: 3min 13s, total: 15min 56s
# Wall time: 26min 41s

# %% [markdown]
# ## Figure 8 (Robustness to stoichiometric errors)

# %%
# %%time
TD.getFigure(8,saved=False)
# Out:
# CPU times: user 15min 34s, sys: 2min 20s, total: 17min 55s
# Wall time: 23min 11s

# %% [markdown]
# ## Figure 9 (Extracellular metabolite prediction)

# %%
# %%time
TD.getFigure(9)
# Out:
# CPU times: user 29.4 s, sys: 1min 9s, total: 1min 38s
# Wall time: 2min 51s

# %% [markdown]
# ## Figure 10 (Comparison with COBRA predictions)

# %%
# %%time
TD.getFigure(10,saved=False)
# Out:
# CPU times: user 20min 58s, sys: 8min 11s, total: 29min 10s
# Wall time: 41min 46s

# %% [markdown]
# ## Figure 11 (Metabolite labeling prediction)

# %%
# %%time
TD.getFigure(11,saved=False)
# Out:
# CPU times: user 20min 58s, sys: 5min 45s, total: 26min 44s
# Wall time: 36min 51s

# %% [markdown]
# # Supplementary figures

# %% [markdown]
# ## Supp. figure 1-3 (Fits)

# %%
# %%time
TD.getSuppFigure(1)
# Out:
# CPU times: user 3min 13s, sys: 668 ms, total: 3min 13s
# Wall time: 3min 13s

# %% [markdown]
# ## Supp. figure 4-12 (Flux maps)

# %%
# %%time
TD.getSuppFigure(4)
# Out:
# svgin:
# /users/hgmartin/libraries/quantmodel/code/core/TOYAexpOLD2.svg
# svgin:
# /users/hgmartin/libraries/quantmodel/code/core/TOYAexpOLD2.svg
# svgin:
# /users/hgmartin/libraries/quantmodel/code/core/TOYAexpOLD2.svg
# svgin:
# /users/hgmartin/libraries/quantmodel/code/core/TOYAexpOLD2.svg
# svgin:
# /users/hgmartin/libraries/quantmodel/code/core/TOYAexpOLD2.svg
# svgin:
# /users/hgmartin/libraries/quantmodel/code/core/TOYAexpOLD2.svg
# svgin:
# /users/hgmartin/libraries/quantmodel/code/core/TOYAexpOLD2.svg
# svgin:
# /users/hgmartin/libraries/quantmodel/code/core/TOYAexpOLD2.svg
# svgin:
# /users/hgmartin/libraries/quantmodel/code/core/TOYAexpOLD2.svg
# CPU times: user 3min 2s, sys: 576 ms, total: 3min 3s
# Wall time: 3min 2s

# %% [markdown]
# ## Supp. figure 13-14 (Extracellular flux prediction for pyk and pgi KOs)

# %%
# %%time
TD.getSuppFigure(13)
# Out:
# CPU times: user 29.8 s, sys: 1min 10s, total: 1min 40s
# Wall time: 2min 51s

# %%
# %%time
TD.getSuppFigure(14)
# Out:
# CPU times: user 29.6 s, sys: 1min 11s, total: 1min 40s
# Wall time: 2min 53s

# %% [markdown]
# ## Supp. figure 15 (Robustness with respect to stoichiometric errors for GLUDy and ICDHyr)

# %%
# %%time
TD.getSuppFigure(15)
# Out:
# CPU times: user 24min 11s, sys: 4min 8s, total: 28min 20s
# Wall time: 36min 33s

# %% [markdown]
# ## Supp. figure 16 (13C MFA)

# %%
# %%time
TD.getSuppFigure(16)
# Out:
# svgin:
# /users/hgmartin/libraries/quantmodel/code/core/TOYA13CMFA.svg
# CPU times: user 7.97 s, sys: 15.6 s, total: 23.6 s
# Wall time: 43.2 s

# %% [markdown]
# ## Supp. figure 17 (Full prediction comparison)

# %%
# %%time
TD.getSuppFigure(17)
# Out:
# CPU times: user 26min 43s, sys: 10min 33s, total: 37min 17s
# Wall time: 57min 46s

# %% [markdown]
# ## Supp. figure 18 (Partial prediction comparison)

# %%
# %%time
TD.getSuppFigure(18)
# Out:
# CPU times: user 3min 29s, sys: 7min 8s, total: 10min 37s
# Wall time: 17min 54s

# %% [markdown]
# ## Supp. figure 19 (OF vs N )

# %% [markdown]
# WARNING: this figure takes **forever**!!!!!!

# %%
#%%time
#TD.getSuppFigure(19)

# %% [markdown]
# # References

# %% [markdown]
# García Martín, Héctor, et al. "A method to constrain genome-scale models with 13 C labeling data." PLoS Comput Biol 11.9 (2015): e1004363.
